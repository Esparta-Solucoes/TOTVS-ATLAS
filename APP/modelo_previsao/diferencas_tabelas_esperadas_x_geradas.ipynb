# %%
import pandas as pd

# %%
df_esperado = pd.read_excel('dados_previsao_esperados.xlsx')
df_gerado = pd.read_csv('dados_previsao_output.csv')

# %%
df_esperado
# Out:
#    historico Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  dt_upload     cd_cli   vl_total  vl_desconto    cd_prod        qtd
#
#   Unnamed: 6 dados_clientes    Unnamed: 8         Unnamed: 9 nps_relacional  \
# 0  fat_faixa    ds_segmento  modal_comerc  situacao_contrato   resposta_NPS
#
#   dados previstos (próximos 6 meses?)        Unnamed: 12  \
# 0                        mes_previsao  vl_total_previsao
#
#             Unnamed: 13                 Unnamed: 14            Unnamed: 15
# 0  vl_desconto_previsao  situacao_contrato_previsao  resposta_NPS_previsao

# %%
df_gerado.head(10)
# Out:
#   cd_cliente  vl_total_historico  vl_desconto_historico  \
# 0     T00053        2.547591e+05               0.000000
# 1     T00082        4.526791e+05               0.000000
# 2     T00145        7.284864e+02               0.000000
# 3     T00336        4.650346e+05               0.000000
# 4     T00673        1.831241e+05          168722.441836
# 5     T00686        1.006591e+06               0.000000
# 6     T01085        3.832582e+05           67633.654167
# 7     T01104        1.954125e+05               0.000000
# 8     T01127        1.458673e+05           39308.588704
# 9     T01134        3.278523e+06          870591.788055
#
#    qtd_produtos_historico                      fat_faixa  \
# 0                     118    Faixa 05 - De 35 M ate 50 M
# 1                     245    Faixa 04 - De 25 M ate 35 M
# 2                      31    Faixa 03 - De 15 M ate 25 M
# 3                      54  Faixa 08 - De 150 M ate 300 M
# 4                     108    Faixa 03 - De 15 M ate 25 M
# ...
